# %% [markdown]
# ![image info](https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/images/banner_1.png)

# %% [markdown]
# # Taller: Construcción e implementación de árboles de decisión y métodos de ensamblaje
#
# En este taller podrá poner en práctica los sus conocimientos sobre construcción e implementación de árboles de decisión y métodos de ensamblajes. El taller está constituido por 9 puntos, 5 relacionados con árboles de decisión (parte A) y 4 con métodos de ensamblaje (parte B).

# %% [markdown]
# ## Parte A - Árboles de decisión
#
# En esta parte del taller se usará el conjunto de datos de Capital Bikeshare de Kaggle, donde cada observación representa el alquiler de bicicletas durante una hora y día determinado. Para más detalles puede visitar los siguientes enlaces: [datos](https://archive.ics.uci.edu/ml/machine-learning-databases/00275/Bike-Sharing-Dataset.zip), [dicccionario de datos](https://archive.ics.uci.edu/ml/datasets/Bike+Sharing+Dataset#).

# %% [markdown]
# ### Datos prestamo de bicicletas

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importación de librerías
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeRegressor, export_graphviz, DecisionTreeClassifier
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
# Lectura de la información de archivo .csv
bikes = pd.read_csv('https://raw.githubusercontent.com/davidzarruk/MIAD_ML_NLP_2023/main/datasets/bikeshare.csv', index_col='datetime', parse_dates=True)

# Renombrar variable "count" a "total"
bikes.rename(columns={'count':'total'}, inplace=True)

# Crear la hora como una variable 
bikes['hour'] = bikes.index.hour

# Visualización de los datos
bikes.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  total  hour
# datetime
# 2011-01-01 00:00:00        81        0.0       3          13     16     0
# 2011-01-01 01:00:00        80        0.0       8          32     40     1
# 2011-01-01 02:00:00        80        0.0       5          27     32     2
# 2011-01-01 03:00:00        75        0.0       3          10     13     3
# 2011-01-01 04:00:00        75        0.0       0           1      1     4

# %% [markdown]
# ### Punto 1 - Análisis descriptivo
#
# Ejecute las celdas 1.1 y 1.2. A partir de los resultados realice un análisis descriptivo sobre las variables "season" y "hour", escriba sus inferencias sobre los datos. Para complementar su análisis puede usar métricas como máximo, mínimo, percentiles entre otros.

# %%
# Celda 1.1
bikes.groupby('season').total.mean()
# Out:
# season
# 1    116.343261
# 2    215.251372
# 3    234.417124
# 4    198.988296
# Name: total, dtype: float64

# %%
# Celda 1.2
bikes.groupby('hour').total.mean()
# Out:
# hour
# 0      55.138462
# 1      33.859031
# 2      22.899554
# 3      11.757506
# 4       6.407240
# 5      19.767699
# 6      76.259341
# 7     213.116484
# 8     362.769231
# 9     221.780220
# 10    175.092308
# 11    210.674725
# 12    256.508772
# 13    257.787281
# 14    243.442982
# 15    254.298246
# 16    316.372807
# 17    468.765351
# 18    430.859649
# 19    315.278509
# 20    228.517544
# 21    173.370614
# 22    133.576754
# 23     89.508772
# Name: total, dtype: float64

# %% [markdown]
# De la celda 1.1 es importante tener en cuenta que en la página comentada anteriormente: https://archive.ics.uci.edu/dataset/275/bike+sharing+dataset
#
# nos indica lo siguiente: season (1:winter, 2:spring, 3:summer, 4:fall)
#
# asímismo del total que anteriormente era count y es lo que sería
# cnt: count of total rental bikes including both casual and registered
#
# Por lo anterior, podemos inferir que estamos hablando del promedio del conteo total de bicicletas alquiladas que podrían ser casual y registered. En esto podemos decir que para winter (Invierno) tenemos un promedio de: 116.343261, para spring (Primavera): 215.251372, para summer (Verano): 234.417124 y por ultimo fall (Otoño): 198.988296.
#
# Los resultados nos están indicando que en verano es donde hay mayor probabilidad de alquilar una bicicleta y es muy solicitado, en los que le sigue primavera, otoño y por último invierno. Es decir que se prefiere andar en bicicleta en climas mas agradables y calurosos, que en clima frio.
#
# Para la celda 2.2 estamos hablando de hour lo que nos indica:
# hour (0 to 23)
#
# Esto está obteniendo el promedio del total en cada hora de las bicicletas alquiladas, en esta ocasión a simple vista podemos ver que a las 17 horas, indicando la 5pm es la hora donde mas se alquilan bicicletas. También podríamos decir que desde las 7 de la mañana hasta las 10 de la noche, siempre hay gran cantidad de bicicletas que van a ser alquiladas, por ende en el resto de horario el promedio disminuye, es decir que entre las 11 de la noche hasta las 6:59 la cantidad de bicicletas es poco.

# %%
bikes.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %% [markdown]
# Para complementar el análisis,
# 1. Podemos ver que no hay valores nulos en ninguna de las columnas que están allí. Es decir todos tienen datos que nos sirve para que pueda ser analizada.
# 2. También en temas de promedio podemos ver que de las bicicletas que serían alquiladas pueden ser casual o registered, pues se puede ver que registered tiene un valor mucho mayor con 155 y casual con 36
# 3. Otro punto a tener en cuenta en la variable season, el 25% de los datos tiene el valor 2:spring (primavera), para el 50% de los datos está el: 3:summer (verano) y el 75% de los datos están en 4:fall (Otoño) Esto nos indica que no tenemos mucha data al respecto de la temporada en que estemos con respecto al 1:winter (Invierno)
# 4. En Holiday, 0: no es festivo y 1: es festivo. Y vemos que la mayoría de datos están en 0 por ende, la gente alquila bicicletas que en días hábiles y en festivos, prefieren no andar cicla
# 5. Para workingday se nos dice: if day is neither weekend nor holiday is 1, otherwise is 0. Al ver el describe nos indica que los datos están mas concentrado en 50% y 75%  en 1. Es decir que la mayoría estaría alquilando bicicleta en días laborales
# 6. Para weather se indica lo siguiente: - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 		- 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# 		- 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
#    Con lo anterior podemos decir que el 50% de los datos está concentrado en 1, el 75% de los datos en 2 y podemos ver que el weather en 3 y 4 no hay muchos datos al respecto y están repartidas.
# 7. Temp es la temperatura donde está medidos por celsius lo que nos indica que la mayoría de personas que los datos indica aquí entre el 50% y 75% que están concentrados entre 20 y 26 grados celsius respectivamente esto se puede inferir que se prefiere andar en bicicleta en climas que no sean tan frios pero tampoco tan calientes, es un clima muy agradable. Podríamos imaginarnos clima como por ejemplo, Medellín o Bucaramanga buscando como una similitud.
# 8. En Atemp es como el cuerpo percibe la temperatura, donde igualmente se intenta asemejar un poco al clima de temp. En este caso el 25% sería 16, para 50% y 75% estaría entre 24 y 31. Igualmente un clima que se sienta comodo, tendiendo un poco al clima caliente
# 9. Humidity. Humedad relativa que indica en este caso que es alto. Entre 47 a 77
# 10. windspeed. Que tiende estar bajo, para que sea mas facil andar en la bicicleta y es mas favorable, porque estamos hablando de la velocidad del viento y para ello pues vemos que están bajos que 20, entonces es razonable esos valores bajos para comodidad y andar normalmente en bicicleta.

# %% [markdown]
# ### Punto 2 - Análisis de gráficos
#
# Primero ejecute la celda 2.1 y asegúrese de comprender el código y el resultado. Luego, en cada una de celdas 2.2 y 2.3 escriba un código que genere una gráfica del número de bicicletas rentadas promedio para cada valor de la variable "hour" (hora) cuando la variable "season" es igual a 1 (invierno) e igual a 3 (verano), respectivamente. Analice y escriba sus hallazgos.

# %%
# Celda 2.1 - rentas promedio para cada valor de la variable "hour"
bikes.groupby('hour').total.mean().plot()
# Out:
# <Axes: xlabel='hour'>

# %%
# Celda 2.2 - "season"=1 escriba su código y hallazgos 
bikes[bikes['season'] == 1].groupby('hour').total.mean().plot()
# Out:
# <Axes: xlabel='hour'>

# %%
# Celda 2.3 - "season"=3 escriba su código y hallazgos 
bikes[bikes['season'] == 3].groupby('hour').total.mean().plot()
# Out:
# <Axes: xlabel='hour'>

# %% [markdown]
# Por lo anterior en las 3 gráficas, curiosamente tiene el mismo comportamiento en las mismas horas en cuanto a subida y bajada de lo que sería el promedio de ciclas alquiladas en las horas cuando son todas las temporadas, cuando es invierno y cuando es verano. Podemos inferir:
# 1. En todos el pico mas bajo es antes de la 5 de mañana y probablemente despues de las 19 horas es donde comienza a bajar mucho la cantidad de alquilar bicicletas.
# 2. El pico mas alto es cuando está aproximadamente entre 15 y 17 que es donde muchas personas alquilan las bicicletas y hay una subida de solicitudes.
# 3. Lo mismo sucede que hay una alta entre las 5 de la mañana hasta las 7, 8 de la mañana aproximadamente.
# 4. Entre 10 y 15 es un promedio regular donde hay un movimiento movido tendiendo hacia arriba para alquilar bicicleta.

# %% [markdown]
# ### Punto 3 - Regresión lineal
# En la celda 3 ajuste un modelo de regresión lineal a un conjunto de train de datos, utilizando "total" como variable de respuesta y "season" y "hour" como las únicas variables predictoras, teniendo en cuenta que la variable "season" es categórica. Luego, imprima los coeficientes e interprételos. ¿Cuáles son las limitaciones de la regresión lineal en este caso?

# %%
# Celda 3

# Codificar variable categórica
bikes_season = bikes.copy()
season_dummies = pd.get_dummies(bikes['season'], prefix='season', drop_first=True)
bikes_season = pd.concat([bikes, season_dummies], axis=1)

#seleccion de variables predictoras
XTotal = bikes_season[['season_2', 'season_3', 'season_4', 'hour']]
yTotal = bikes_season[['total']]

#División dataset
X_train, X_test, y_train, y_test = train_test_split(XTotal, yTotal, test_size=0.33, random_state=0)

#Train model
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

#Evaluación de error del modelo
print(model,np.sqrt(mean_squared_error(y_pred, y_test)))
#Coeficiente
print(model.intercept_)
print(model.coef_)
# Out:
# LinearRegression() 160.13875579927017
# [-9.56307127]
# [[100.90776793 119.01866421  87.2473903   10.62873885]]

# %% [markdown]
# Se puede ver que el intercepto es un valor de: -9.56307127 esto sería season 1:winter, season 2 spring: 100.90776793, season 3 summer: 119.01866421, season 4 fall: 87.2473903 y hour: 10.62873885
#
# - En el intercepto el valor es negativo, y no tiene sentido ya que no se puede alquilar -9 bicicletas
# - Aquí igualmente podemos ver que en season 3 que es summer (verano) sigue siendo la epoca en donde mas se alquilan bicicletas
# - Por último en horas, cada vez que aumenta se alquilan 10 bicicletas más.
#
# La limitación de la regresión lineal, considero yo que podría ser por la variable hora, porque como vimos anteriormente en las gráficas cuando se hizo la comparación del promedio total en diferentes season y en su totalidad, vimos un comportamiento similar, en donde había momentor por la mañana de subida y parte de la tarde muestra que hay bajada y otra subida y al final una baja completamente. Esto nos quiere decir que no puede ser una regresión lineal, sino que hay variaciones durante el tiempo. También y es que no podemos decir que alquilar una bicicleta en season 1 sea -9 en invierno, aunque se entienda que sea el que menos se solicita en la temporada.

# %% [markdown]
# ### Punto 4 - Árbol de decisión manual
# En la celda 4 cree un árbol de decisiones para pronosticar la variable "total" iterando **manualmente** sobre las variables "hour" y  "season". El árbol debe tener al menos 6 nodos finales.

# %%
# Celda 4
# Codificar variable categórica
bikes_season = bikes.copy()
season_dummies = pd.get_dummies(bikes['season'], prefix='season', drop_first=True)
bikes_season = pd.concat([bikes, season_dummies], axis=1)

#seleccion de variables predictoras
X = bikes_season[['season_2', 'season_3', 'season_4', 'hour']]
y = bikes_season['total']

# %%
def gini(y):
    if y.shape[0] == 0:
        return 0
    else:
        return 1 - (y.mean()**2 + (1 - y.mean())**2)

# %%
def gini_impurity(X_col, y, split):
    
    filter_l = X_col < split
    y_l = y.loc[filter_l]
    y_r = y.loc[~filter_l]
    
    n_l = y_l.shape[0]
    n_r = y_r.shape[0]
    
    gini_y = gini(y)
    gini_l = gini(y_l)
    gini_r = gini(y_r)
    
    gini_impurity_ = gini_y - (n_l / (n_l + n_r) * gini_l + n_r / (n_l + n_r) * gini_r)
    
    return gini_impurity_

# %%
def best_split(X, y, num_pct=10):
    
    features = range(X.shape[1])
    
    best_split = [0, 0, 0]  # j, split, gain
    
    # Para todas las varibles 
    for j in features:

        if X.iloc[:, j].dtype == 'bool':
            splits = [0.5]
        else:
            splits = np.percentile(X.iloc[:, j], np.arange(0, 100, 100.0 / (num_pct+1)).tolist())
            splits = np.unique(splits)[1:]
        
        # Para cada partición
        for split in splits:
            gain = gini_impurity(X.iloc[:, j], y, split)
                        
            if gain > best_split[2]:
                best_split = [j, split, gain]
    
    return best_split

# %%
# Definición de la función tree_grow para hacer un crecimiento recursivo del árbol
def tree_grow(X, y, level=0, min_gain=0.001, max_depth=None, num_pct=10):
    
    # Si solo es una observación
    if X.shape[0] == 1:
        tree = dict(y_pred=y.iloc[:1].values[0], y_prob=0.5, level=level, split=-1, n_samples=1, gain=0)
        return tree
    
    # Calcular la mejor división
    j, split, gain = best_split(X, y, num_pct)
    
    # Guardar el árbol y estimar la predicción
    y_pred = int(y.mean() >= 0.5) 
    y_prob = (y.sum() + 1.0) / (y.shape[0] + 2.0)  # Corrección Laplace 
    
    tree = dict(y_pred=y_pred, y_prob=y_prob, level=level, split=-1, n_samples=X.shape[0], gain=gain)
    # Revisar el criterio de parada 
    if gain < min_gain:
        return tree
    if max_depth is not None:
        if level >= max_depth:
            return tree   
    
    # Continuar creando la partición
    filter_l = X.iloc[:, j] < split
    X_l, y_l = X.loc[filter_l], y.loc[filter_l]
    X_r, y_r = X.loc[~filter_l], y.loc[~filter_l]
    tree['split'] = [j, split]

    # Siguiente iteración para cada partición
    
    tree['sl'] = tree_grow(X_l, y_l, level + 1, min_gain=min_gain, max_depth=max_depth, num_pct=num_pct)
    tree['sr'] = tree_grow(X_r, y_r, level + 1, min_gain=min_gain, max_depth=max_depth, num_pct=num_pct)
    
    return tree

# %%
tree = tree_grow(X, y, level=0, min_gain=0.001, max_depth=3, num_pct=10)
tree
# Out:
# {'y_pred': 1,
#  'y_prob': np.float64(191.53903379867745),
#  'level': 0,
#  'split': [3, np.float64(8.0)],
#  'n_samples': 10886,
#  'gain': np.float64(18268.811823533004),
#  'sl': {'y_pred': 1,
#   'y_prob': np.float64(55.40711902113459),
#   'level': 1,
#   'split': [3, np.float64(7.0)],
#   'n_samples': 3594,
#   'gain': np.float64(7207.700659959655),
#   'sl': {'y_pred': 1,
#    'y_prob': np.float64(32.561604584527224),
#    'level': 2,
#    'split': [3, np.float64(6.0)],
#    'n_samples': 3139,
#    'gain': np.float64(646.8008927589567),
#    'sl': {'y_pred': 1,
#     'y_prob': np.float64(25.15934475055845),
#     'level': 3,
#     'split': -1,
#     'n_samples': 2684,
#     'gain': np.float64(382.8088308604629)},
#    'sr': {'y_pred': 1,
#     'y_prob': np.float64(75.92778993435448),
#     'level': 3,
#     'split': -1,
#     'n_samples': 455,
#     'gain': np.float64(281.5741570441587)}},
#   'sr': {'y_pred': 1,
#    'y_prob': np.float64(212.18599562363238),
# ...

# %%
# Definición de la función tree_predict para hacer predicciones según las variables 'X' y el árbol 'tree'

def tree_predict(X, tree, proba=False):
    
    predicted = np.ones(X.shape[0])

    # Revisar si es el nodo final
    if tree['split'] == -1:
        if not proba:
            predicted = predicted * tree['y_pred']
        else:
            predicted = predicted * tree['y_prob']
            
    else:
        
        j, split = tree['split']
        filter_l = (X.iloc[:, j] < split)
        X_l = X.loc[filter_l]
        X_r = X.loc[~filter_l]

        if X_l.shape[0] == 0:  # Si el nodo izquierdo está vacio solo continua con el derecho 
            predicted[~filter_l] = tree_predict(X_r, tree['sr'], proba)
        elif X_r.shape[0] == 0:  #  Si el nodo derecho está vacio solo continua con el izquierdo
            predicted[filter_l] = tree_predict(X_l, tree['sl'], proba)
        else:
            predicted[filter_l] = tree_predict(X_l, tree['sl'], proba)
            predicted[~filter_l] = tree_predict(X_r, tree['sr'], proba)

    return predicted

# %%
tree_predict(X, tree)
# Out:
# array([1., 1., 1., ..., 1., 1., 1.], shape=(10886,))

# %% [markdown]
# ### Punto 5 - Árbol de decisión con librería
# En la celda 5 entrene un árbol de decisiones con la **librería sklearn**, usando las variables predictoras "season" y "hour" y calibre los parámetros que considere conveniente para obtener un mejor desempeño. Recuerde dividir los datos en conjuntos de entrenamiento y validación para esto. Comente el desempeño del modelo con alguna métrica de desempeño de modelos de regresión y compare desempeño con el modelo del punto 3.
#
# Tenga en cuenta que, a diferencia del laboratorio, este problema es de regresión. Por lo tanto, para hacer cada split del árbol se debe utilizar algún criterio apropiado para problemas de regresión.

# %%
# Celda 5

# Codificar variable categórica
bikes_season = bikes.copy()
season_dummies = pd.get_dummies(bikes['season'], prefix='season', drop_first=True)
bikes_season = pd.concat([bikes, season_dummies], axis=1)

#seleccion de variables predictoras
X = bikes_season[['season_2', 'season_3', 'season_4', 'hour']]
y = bikes_season['total']

#División dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# Lista de valores para calibrar el criterio de parada de máxima profundidad (max_depth)
max_depth_range = range(1, 21)

# Lista para guardar los valores del RMSE para cada valor de máxima profundidad (max_depth)
rmse_scores = []

for depth in max_depth_range:
    # Definición del árbol de decisión usando DecisionTreeClassifier de la libreria sklearn
    clf = DecisionTreeRegressor(max_depth=depth, random_state=1)
    rmse_scores.append(-cross_val_score(clf, X_train, y_train, cv=10, scoring='neg_root_mean_squared_error').mean())

# %%
# Gráfica max_depth versus RMSE (error del modelo)
plt.plot(max_depth_range, rmse_scores)
plt.xlabel('max_depth')
plt.ylabel('RMSE')
# Out:
# Text(0, 0.5, 'RMSE')

# %%
# Mejor accuracy (desempeño del modelo) y su correspondiente max_depth
sorted(zip(rmse_scores, max_depth_range))[0]
# Out:
# (np.float64(113.38037242056912), 10)

# %%
# max_depth=10 fue el mejor, se ajusta un árbol usando este valor 
clf = DecisionTreeRegressor(max_depth=10, random_state=1)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=10, random_state=1)

# %%
# Uso de la función .feature_importances_ para obtener la importancia de cada variable
pd.DataFrame({'feature':['season_2', 'season_3', 'season_4', 'hour'], 'importance':clf.feature_importances_}).sort_values('importance')
# Out:
#     feature  importance
# 0  season_2    0.043331
# 1  season_3    0.044535
# 2  season_4    0.064215
# 3      hour    0.847919

# %%
pd.Series(cross_val_score(clf, X_train, y_train, cv=10)).describe()
# Out:
# count    10.000000
# mean      0.607544
# std       0.021387
# min       0.561733
# 25%       0.597000
# 50%       0.610358
# 75%       0.621383
# max       0.634040
# dtype: float64

# %%
y_pred = clf.predict(X_test)

# %%
print(clf,np.sqrt(mean_squared_error(y_pred, y_test)))
# Out:
# DecisionTreeRegressor(max_depth=10, random_state=1) 115.73032667446998

# %% [markdown]
# Con respecto al modelo regresión realizado en el punto 3 se obtiene el siguiente resultado
# LinearRegression() 160.13875579927017
#
# y en esta de arbol de regresión con una profundidad de 10 se obtiene el resultado de 115.73032667446998
#
# Se puede concluir que el arbol de regresión que tiene menor RMSE es mejor que LinearRegression

# %% [markdown]
# ## Parte B - Métodos de ensamblajes
# En esta parte del taller se usará el conjunto de datos de Popularidad de Noticias Online. El objetivo es predecir si la notica es popular o no, la popularidad está dada por la cantidad de reacciones en redes sociales. Para más detalles puede visitar el siguiente enlace: [datos](https://archive.ics.uci.edu/ml/datasets/online+news+popularity).

# %% [markdown]
# ### Datos popularidad de noticias

# %%
# Lectura de la información de archivo .csv
df = pd.read_csv('https://raw.githubusercontent.com/davidzarruk/MIAD_ML_NLP_2023/main/datasets/mashable.csv', index_col=0)
df.head()
# Out:
#                                                  url  timedelta  \
# 0  http://mashable.com/2014/12/10/cia-torture-rep...       28.0
# 1  http://mashable.com/2013/10/18/bitlock-kicksta...      447.0
# 2  http://mashable.com/2013/07/24/google-glass-po...      533.0
# 3  http://mashable.com/2013/11/21/these-are-the-m...      413.0
# 4  http://mashable.com/2014/02/11/parking-ticket-...      331.0
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0             9.0             188.0         0.732620               1.0
# 1             7.0             297.0         0.653199               1.0
# 2            11.0             181.0         0.660377               1.0
# 3            12.0             781.0         0.497409               1.0
# 4             8.0             177.0         0.685714               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  ...  \
# 0                  0.844262        5.0             1.0       1.0  ...
# ...

# %%
# Definición variable de interes y variables predictoras
X = df.drop(['url', 'Popular'], axis=1)
y = df['Popular']
y.mean()
# Out:
# np.float64(0.5)

# %%
# División de la muestra en set de entrenamiento y prueba
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Punto 6 - Árbol de decisión y regresión logística
# En la celda 6 construya un árbol de decisión y una regresión logística. Para el árbol calibre al menos un parámetro y evalúe el desempeño de cada modelo usando las métricas de Accuracy y F1-Score.

# %%
# Celda 6
models = {'lr': LogisticRegression(),
          'dt': DecisionTreeClassifier(max_depth=10)
         }

# %%
# Entrenamiento (fit) de cada modelo
for model in models.keys():
    models[model].fit(X_train, y_train)

# %%
y_pred = pd.DataFrame(index=X_test.index, columns=models.keys())
for model in models.keys():
    y_pred[model] = models[model].predict(X_test)

# %%
for model in models.keys():
    print("accuracy", model,metrics.accuracy_score(y_pred[model], y_test))
    print("f1_score", model,metrics.f1_score(y_pred[model], y_test))
# Out:
# accuracy lr 0.6146666666666667
# f1_score lr 0.6131191432396251
# accuracy dt 0.578
# f1_score dt 0.5886939571150097

# %% [markdown]
# ### Punto 7 - Votación Mayoritaria
# En la celda 7 elabore un esamble con la metodología de **Votación mayoritaria** compuesto por 300 muestras bagged donde:
#
# -las primeras 100 muestras de bootstrap vienen de árboles de decisión donde max_depth tome un valor de su elección\
# -las segundas 100 muestras de bootstrap vienen de árboles de decisión donde min_samples_leaf tome un valor de su elección\
# -las últimas 100 muestras de bootstrap vienen de regresiones logísticas
#
# Evalúe cada uno de los tres modelos de manera independiente utilizando las métricas de Accuracy y F1-Score, luego evalúe el ensamble de modelos y compare los resultados.
#
# Nota:
#
# Para este ensamble de 300 modelos, deben hacer votación mayoritaria. Esto lo pueden hacer de distintas maneras. La más "fácil" es haciendo la votación "manualmente", como se hace a partir del minuto 5:45 del video de Ejemplo práctico de emsablajes en Coursera. Digo que es la más fácil porque si hacen la votación mayoritaria sobre las 300 predicciones van a obtener lo que se espera.
#
# Otra opción es: para cada uno de los 3 tipos de modelos, entrenar un ensamble de 100 modelos cada uno. Predecir para cada uno de esos tres ensambles y luego predecir como un ensamble de los 3 ensambles. La cuestión es que la votación mayoritaria al usar los 3 ensambles no necesariamente va a generar el mismo resultado que si hacen la votación mayoritaria directamente sobre los 300 modelos. Entonces, para los que quieran hacer esto, deben hacer ese último cálculo con cuidado.
#
# Para los que quieran hacerlo como ensamble de ensambles, digo que se debe hacer el ensamble final con cuidado por lo siguiente. Supongamos que:
#
# * para los 100 árboles del primer tipo, la votación mayoritaria es: 55% de los modelos predicen que la clase de una observación es "1"
# * para los 100 árboles del segundo tipo, la votación mayoritaria es: 55% de los modelos predicen que la clase de una observación es "1"
# * para las 100 regresiones logísticas, la votación mayoritaria es: 10% de los modelos predicen que la clase de una observación es "1"
#
# Si se hace la votación mayoritaria de los 300 modelos, la predicción de esa observación debería ser: (100*55%+100*55%+100*10%)/300 = 40% de los modelos votan porque la predicción debería ser "1". Es decir, la predicción del ensamble es "0" (dado que menos del 50% de modelos predijo un 1).
#
# Sin embargo, si miramos cada ensamble por separado, el primer ensamble predice "1", el segundo ensamble predice "1" y el último ensamble predice "0". Si hago votación mayoritaria sobre esto, la predicción va a ser "1", lo cual es distinto a si se hace la votación mayoritaria sobre los 300 modelos.

# %%
# Celda 7
# Creación de 100 muestras de bootstrap
n_estimators = 100
np.random.seed(123)

n_samples = X_train.shape[0]
samples = [np.random.choice(a=n_samples, size=n_samples, replace=True) for _ in range(n_estimators)]

np.random.seed(123) 
seeds = np.random.randint(1, 10000, size=n_estimators)

trees_depth = {}
for i in range(n_estimators):
    trees_depth[i] = DecisionTreeClassifier(max_depth=5, random_state=seeds[i])
    trees_depth[i].fit(X_train.iloc[samples[i]], y_train.iloc[samples[i]])

# %%
trees_min = {}
for i in range(100):
    trees_min[i] = DecisionTreeClassifier(min_samples_leaf=10, random_state=seeds[i])
    trees_min[i].fit(X_train.iloc[samples[i]], y_train.iloc[samples[i]])

# %%
regresion_logistica = {}
for i in range(100):
    regresion_logistica[i] = LogisticRegression(max_iter=1000)
    regresion_logistica[i].fit(X_train.iloc[samples[i]], y_train.iloc[samples[i]])

# %%
y_pred_df = pd.DataFrame(index=X_test.index, columns=list(range(n_estimators)))
for i in range(n_estimators):
    y_pred_df.iloc[:, i] = trees_depth[i].predict(X_test)

y_pred_depth = (y_pred_df.sum(axis=1) >= (n_estimators / 2)).astype(np.int64)

# %%
y_pred_df = pd.DataFrame(index=X_test.index, columns=list(range(n_estimators)))
for i in range(n_estimators):
    y_pred_df.iloc[:, i] = trees_min[i].predict(X_test)

y_pred_min = (y_pred_df.sum(axis=1) >= (n_estimators / 2)).astype(np.int64)

# %%
y_pred_df = pd.DataFrame(index=X_test.index, columns=list(range(n_estimators)))
for i in range(n_estimators):
    y_pred_df.iloc[:, i] = regresion_logistica[i].predict(X_test)

y_pred_regresion = (y_pred_df.sum(axis=1) >= (n_estimators / 2)).astype(np.int64)

# %%
print("Arbol - max depth")
print(metrics.accuracy_score(y_pred_depth, y_test))
print(metrics.f1_score(y_pred_depth, y_test))

print("Arbol - min samples leaf")
print(metrics.accuracy_score(y_pred_min, y_test))
print(metrics.f1_score(y_pred_min, y_test ))

print("Regresion logistica")
print(metrics.accuracy_score(y_pred_regresion, y_test))
print(metrics.f1_score(y_pred_regresion, y_test))
# Out:
# Arbol - max depth
# 0.6553333333333333
# 0.6527871054398925
# Arbol - min samples leaf
# 0.646
# 0.6467065868263473
# Regresion logistica
# 0.6153333333333333
# 0.6023432115782219

# %%
all_prediction = pd.DataFrame(index=X_test.index)

# Árboles depth
for i in range(100):
    all_prediction[f"depth_{i}"] = trees_depth[i].predict(X_test)

# Árboles min_samples
for i in range(100):
    all_prediction[f"min_{i}"] = trees_min[i].predict(X_test)

# Regresión logística
for i in range(100):
    all_prediction[f"log_{i}"] = regresion_logistica[i].predict(X_test)

# Votación mayoritaria sobre 300 modelos
ensemble = (all_prediction.sum(axis=1) >= 150).astype(np.int64)

ensemble_1_accuracy = metrics.accuracy_score(ensemble, y_test)
ensemble_1_f1 = metrics.f1_score(ensemble, y_test)
print(metrics.accuracy_score(ensemble, y_test))
print(metrics.f1_score(ensemble, y_test))
# Out:
# 0.6366666666666667
# 0.6274777853725222

# %% [markdown]
# De los resultado se puede ver que el accuracy y f1-score de esemble es mayor a regresión logística pero es menor que el de ambos arbol de decisión realizado

# %% [markdown]
# ### Punto 8 - Votación Ponderada
# En la celda 8 elabore un ensamble con la metodología de **Votación ponderada** compuesto por 300 muestras bagged para los mismos tres escenarios del punto 7. Evalúe los modelos utilizando las métricas de Accuracy y F1-Score

# %%
# Celda 8

samples_oob = []
# Obtención de las observaciones fuera de la bolsa "out-of-bag" para cada muestra
for sample in samples:
    samples_oob.append(sorted(set(range(n_samples)) - set(sample)))

# %%
# Estimación de los errores OOB para cada clasificador
errors = []

for i in range(n_estimators):
    y_pred_ = trees_depth[i].predict(X_train.iloc[samples_oob[i]])
    errors.append(1 - metrics.accuracy_score(y_train.iloc[samples_oob[i]], y_pred_)) 

for i in range(n_estimators):
    y_pred_ = trees_min[i].predict(X_train.iloc[samples_oob[i]])
    errors.append(1 - metrics.accuracy_score(y_train.iloc[samples_oob[i]], y_pred_))

for i in range(n_estimators):
    y_pred_ = regresion_logistica[i].predict(X_train.iloc[samples_oob[i]])
    errors.append(1 - metrics.accuracy_score(y_train.iloc[samples_oob[i]], y_pred_))

# %%
# Visualización de OOB para cada árbol
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

plt.scatter(range(len(errors)), errors)
plt.xlim([0, len(errors)])
plt.title('OOB error of each model')
# Out:
# Text(0.5, 1.0, 'OOB error of each model')

# %%
# Obtención de los pesos alpha de cada modelo de acuerdo al error OOB
errors = np.array(errors)
alpha = (1 - errors) / (1 - errors).sum()

# %%
# Ponderación de las predicciones con los pesos alpha
weighted_sum_1 = ((all_prediction ) * alpha).sum(axis=1)
weighted_sum_1.head(20)
# Out:
# 1483    0.942575
# 2185    0.838817
# 2520    0.794883
# 3721    0.877233
# 3727    0.073891
# 4524    0.580071
# 234     0.064344
# 4735    0.188024
# 5839    0.409972
# 2939    0.693305
# 3053    0.907905
# 867     0.871369
# 276     0.856017
# 5798    0.076662
# 3512    0.942794
# 5789    0.076199
# 3198    0.847905
# 5908    0.964906
# 5718    0.184136
# 2687    0.077581
# dtype: float64

# %%
# Desempeño al hacer votación ponderada
y_pred = (weighted_sum_1 >= 0.5).astype(np.int64)

ensemble_2_accuracy = metrics.accuracy_score(y_pred, y_test)
ensemble_2_f1 = metrics.f1_score(y_pred, y_test)

# %% [markdown]
# ### Punto 9 - Comparación y análisis de resultados
# En la celda 9 comente sobre los resultados obtenidos con las metodologías usadas en los puntos 7 y 8, compare los resultados y enuncie posibles ventajas o desventajas de cada una de ellas.

# %%
# Celda 9
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title("Comparación de modelos")
ejeX = ['Mayoritaria-Acc', 'Ponderada-Acc', 'Mayoritaria-F1', 'Ponderada-F1']
ejeY = [round(ensemble_1_accuracy,5),round(ensemble_2_accuracy,5),round(ensemble_1_f1,5), round(ensemble_2_f1,5)]
ax.bar(ejeX,ejeY)
def addlabels(x,y,plotP):
    for i in range(len(x)):
        plotP.text(i,y[i],y[i])
addlabels(ejeX,ejeY,plt)
plt.show()

# %% [markdown]
# Con la gráfica anterior es visible que en tema de Accuracy los dos modelos tanto como mayoritaria y ponderada tiene el mismo valor, así que ambos clasifican correctamente la misma cantidad de caso, incluso mayoritaria con mas decimales. y para f1 mayoritaria es mayor que ponderada por decimales, por lo que la votación validando el error oob no generó una mejora significativa.
#
# Considero que para el tema de mayoritario, podría verse afectada las estadísticas dependiendo del modelo. Incluso podríamos decidr que el modelo de regresión logística, hizo que disminuyera lo resultados aún sabiendo que los arboles de decisión habían superado en gran manera las estadísticas.
#
# Pero en mayoritario se hizo facilmente implementarlo para cada uno de los modelos y validar su resultado
#
# Para el tema de votación ponderada, el poder validar y mirar con oob permite tener esas validaciones adicionales y eso permite tener buenos resultados, sin embargo puede no superar a mayoritaria como en esta ocasión.
